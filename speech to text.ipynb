# %%
# !pip install SpeechRecognition

# %%
# !pip install pyttsx3

# %%
import speech_recognition as sr
import pyttsx3

# %%
r=sr.Recognizer()

def SpeakText(command):
    engine=pyttsx3.init()
    engine.say(command)
    engine.runAndWait()

# %%
SpeakText("hello world")

# %%
with sr.Microphone() as source2:
    SpeakText('Silence please, calibrating background noises')
    r.adjust_for_ambient_noise(source2, duration=2)
    SpeakText("Calibrated, now speak!")
    
    audio2=r.listen(source2)
    
    MyText=r.recognize_google(audio2)
    MyText=MyText.lower()
    
    SpeakText("Did you say "+ MyText)

# %%
# !pip install PyAudio

# %%
import speech_recognition as sr
from os import walk

r = sr.Recognizer()
#optional
#r.energy_threshold = 300

def startConvertion(path = 'harvard.wav', lang = 'en-IN'): 
    with sr.AudioFile(path) as source:
        #print('Fetching File')
        audio_file = r.record(source)
        print(r.recognize_google(audio_file, language=lang))
startConvertion()

# %%
responses = {
    "hello": "Hi there!",
    "how are you?": "I'm doing well, thanks for asking.",
    "what is your name?": "My name is TheBot, how can I assist you?",
    "goodbye": "Goodbye, have a nice day!",
}

# function to process user input and generate response
def respond(input_message):
    input_message = input_message.lower()
    for message in responses:
        if message in input_message:
            return responses[message]
    return "I'm sorry, I didn't understand what you said."

# initialize speech recognizer
r = sr.Recognizer()

# main program loop
while True:
    # listen for user input
    with sr.Microphone() as source:
        SpeakText("Speak:")
        audio = r.listen(source)

    # convert speech to text
    try:
        user_input = r.recognize_google(audio)
        SpeakText("You said:"+ user_input)
    except sr.UnknownValueError:
        SpeakText("Sorry, I didn't catch that. Please try again.")
        continue

    # generate response and output to console
    response = respond(user_input)
    SpeakText(response)

# %%
import speech_recognition as sr
from googlesearch import search

# define responses to different input messages
responses = {
    "hello": "Hi there!",
    "how are you?": "I'm doing well, thanks for asking.",
    "what is your name?": "My name is TheBot, how can I assist you?",
    "goodbye": "Goodbye, have a nice day!",
}

# function to process user input and generate response
def respond(input_message):
    input_message = input_message.lower()
    for message in responses:
        if message in input_message:
            return responses[message]

    # search Google for input message
    search_results = list(search(input_message, num_results=1))
    if search_results:
        return f"Here's what I found on Google: {search_results[0]}"
    else:
        return "I'm sorry, I couldn't find anything on Google for that."

# initialize speech recognizer
r = sr.Recognizer()

# main program loop
while True:
    # listen for user input
    with sr.Microphone() as source:
        print("Speak:")
        audio = r.listen(source)

    # convert speech to text
    try:
        user_input = r.recognize_google(audio)
        print("You said:", user_input)
    except sr.UnknownValueError:
        print("Sorry, I didn't catch that. Please try again.")
        continue

    # generate response and output to console
    response = respond(user_input)
    print("Result:", response)

# %%
pip install googlesearch-python

# %%
import speech_recognition as sr
from googlesearch import search
import pyttsx3

# define responses to different input messages
responses = {
    "hello": "Hi there!",
    "how are you?": "I'm doing well, thanks for asking.",
    "what is your name?": "My name is TheBot, how can I assist you?",
    "goodbye": "Goodbye, have a nice day!",
}

# function to process user input and generate response
def respond(input_message):
    input_message = input_message.lower()
    for message in responses:
        if message in input_message:
            return responses[message]

    # search Google for input message
    search_results = list(search(input_message, num_results=1))
    if search_results:
        return search_results[0]
    else:
        return "I'm sorry, I couldn't find anything on Google for that."

# initialize speech recognizer and text-to-speech engine
r = sr.Recognizer()
engine = pyttsx3.init()

# main program loop
while True:
    # listen for user input
    with sr.Microphone() as source:
        print("Speak:")
        audio = r.listen(source)

    # convert speech to text
    try:
        user_input = r.recognize_google(audio)
        print("You said:", user_input)
    except sr.UnknownValueError:
        print("Sorry, I didn't catch that. Please try again.")
        continue

    # generate response and output to console
    response = respond(user_input)
    print("Result:", response)

    # read out search result using text-to-speech engine
    if response.startswith("http"):
        engine.say("Here's what I found on Google:")
        engine.say(response)
        engine.runAndWait()

# %%
# !pip install beautifulsoup4

# %%
import speech_recognition as sr
from googlesearch import search
import requests
from bs4 import BeautifulSoup
import pyttsx3

# define responses to different input messages
responses = {
    "hello": "Hi there!",
    "how are you?": "I'm doing well, thanks for asking.",
    "what is your name?": "My name is TheBot, how can I assist you?",
    "goodbye": "Goodbye, have a nice day!",
}

# function to process user input and generate response
def respond(input_message):
    input_message = input_message.lower()
    for message in responses:
        if message in input_message:
            return responses[message]

    # search Google for input message
    search_results = list(search(input_message, num_results=1))
    if search_results:
        return search_results[0]
    else:
        return "I'm sorry, I couldn't find anything on Google for that."

# function to get sentence from top search result
def get_sentence(search_result):
    page = requests.get(search_result)
    soup = BeautifulSoup(page.content, 'html.parser')
    sentences = soup.find_all('p')
    if sentences:
        return sentences[0].text
    else:
        return "I'm sorry, I couldn't find any sentences on the page."

# initialize speech recognizer and text-to-speech engine
r = sr.Recognizer()
engine = pyttsx3.init()
engine.setProperty('rate', 170)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[1].id)

# main program loop
while True:
    # listen for user input
    with sr.Microphone() as source:
        print("Speak:")
        #engine.say('Hello, I am Hira. How may I assist you today?')
        audio = r.listen(source)

    # convert speech to text
    try:
        user_input = r.recognize_google(audio)
        print("You said:", user_input)
    except sr.UnknownValueError:
        print("Sorry, I didn't catch that. Please try again.")
        continue

    # generate response and output to console
    response = respond(user_input)
    print("Result:", response)

    # read out sentence from search result using text-to-speech engine
    if response.startswith("http"):
        sentence = get_sentence(response)
        engine.say("Here's what I found on Google:")
        engine.say(sentence)
        engine.runAndWait()

# %%
import pyttsx3

# initialize the engine
engine = pyttsx3.init()

# get a list of available voices
voices = engine.getProperty('voices')

# set the voice to a female voice
engine.setProperty('voice', voices[1].id)

# say something
engine.say('Hello, I am Hira. How may I assist you today?')

# run and wait for the speech to finish
engine.runAndWait()

# %%
import requests
from bs4 import BeautifulSoup
import pyttsx3
import speech_recognition as sr
import pyaudio


# Set up the Google search API
API_KEY = 'AIzaSyCybIXbY-GU9d4h4ZTBEUQQnoyO83Mgu0c'
SEARCH_ENGINE_ID = 'e3548772f3e354ba2'


# Set up the text-to-speech engine
engine = pyttsx3.init()
engine.setProperty('rate', 170)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[1].id)

# Set up the speech recognition engine
r = sr.Recognizer()
mic = sr.Microphone()

def SpeakText(command):
    engine=pyttsx3.init()
    engine.say(command)
    engine.runAndWait()
    
def recognize_speech():
    with mic as source:
        r.adjust_for_ambient_noise(source)
        audio = r.listen(source)
    try:
        query = r.recognize_google(audio)
        print(f'You said: {query}')
        return query
    except sr.UnknownValueError:
        print('Sorry, I did not understand what you said')
        return ''
    except sr.RequestError as e:
        print(f'Speech recognition service error: {e}')
        return ''

def search(query):
    # Send the search query to Google
    url = f'https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&q={query}'
    response = requests.get(url)
    results = response.json()['items']

    # Extract the sentences from the search results
    sentences = []
    for result in results:
        soup = BeautifulSoup(result['snippet'], 'html.parser')
        sentence = soup.get_text()
        sentences.append(sentence)
        
         # Use text-to-speech to read out the sentences
    sentence_count = 0
    for sentence in sentences:
        engine.say(sentence)
        engine.runAndWait()
        sentence_count += 1
        if sentence_count == 3:
            break

while True:
    print('Listening...')
    query = recognize_speech()
    if query:
        search(query)

# %%
import requests
from bs4 import BeautifulSoup
import pyttsx3
import speech_recognition as sr
import pyaudio

# Set up the Google search API
API_KEY = 'AIzaSyCybIXbY-GU9d4h4ZTBEUQQnoyO83Mgu0c'
SEARCH_ENGINE_ID = 'e3548772f3e354ba2'

# Set up the text-to-speech engine
engine = pyttsx3.init()

# Set up the speech recognition engine
r = sr.Recognizer()
mic = sr.Microphone()

def recognize_speech():
    with mic as source:
        r.adjust_for_ambient_noise(source)
        audio = r.listen(source)
    try:
        query = r.recognize_google(audio)
        print(f'You said: {query}')
        return query
    except sr.UnknownValueError:
        print('Sorry, I did not understand what you said')
        return ''
    except sr.RequestError as e:
        print(f'Speech recognition service error: {e}')
        return ''

def search(query):
    # Send the search query to Google
    url = f'https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&q={query}'
    response = requests.get(url)
    results = response.json()['items']

    # Extract the sentences from the search results
    sentences = []
    for result in results:
        soup = BeautifulSoup(result['snippet'], 'html.parser')
        sentence = soup.get_text()
        sentences.append(sentence)

    # Use text-to-speech to read out the sentences
    sentence_count = 0
    for sentence in sentences:
        engine.say(sentence)
        engine.runAndWait()
        sentence_count += 1
        if sentence_count == 3:
            break

while True:
    print('Listening...')
    query = recognize_speech()
    if query:
        search(query)

# %%
import pyttsx3
import speech_recognition as sr
import googlesearch

API_KEY = 'AIzaSyCybIXbY-GU9d4h4ZTBEUQQnoyO83Mgu0c'
SEARCH_ENGINE_ID = 'e3548772f3e354ba2'

def SpeakText(command):
    engine=pyttsx3.init()
    engine.say(command)
    engine.runAndWait()
    
# Initialize the speech engine
engine = pyttsx3.init()

# Define the bot's name and introduction message
bot_name = "Google Search Bot"
intro_msg = f"Hi, I'm {bot_name}. I can help you find information on the internet. What would you like me to search for?"

# Say the introduction message
engine.say(intro_msg)
engine.runAndWait()

# Initialize the speech recognizer
r = sr.Recognizer()

# Start the chat loop
while True:
    # Listen for user input through the microphone
    with sr.Microphone() as source:
        SpeakText("Say something!")
        audio = r.listen(source)

    # Convert the speech input to text
    try:
        user_input = r.recognize_google(audio)
        SpeakText(f"You said: {user_input}")

    # Handle any errors that occur during speech recognition
    except sr.UnknownValueError:
        user_input = ""

    # If the user says goodbye, exit the chat loop
    if user_input.lower() in ["goodbye", "bye", "exit", "quit"]:
        print("Goodbye!")
        break

    # Otherwise, search for the user's query on Google and read out the first result
    else:
        try:
            # Search for the user's query
            search_results = list(googlesearch.search(user_input, num_results=1))

            # Get the first result
            first_result = search_results[0]

            # Say the result
            engine.say(f"The top search result for {user_input} is: {first_result}")
            engine.runAndWait()

        # Handle any errors that occur during the search
        except:
            engine.say("Sorry, I couldn't find any results for that search.")
            engine.runAndWait()

# %%
import pyttsx3
import speech_recognition as sr
import googlesearch
import requests
from bs4 import BeautifulSoup

def SpeakText(command):
    engine=pyttsx3.init()
    engine.say(command)
    engine.runAndWait()
# Initialize the speech engine
engine = pyttsx3.init()

# Define the bot's name and introduction message
bot_name = "Google Search Bot"
intro_msg = f"Hi, I'm {bot_name}. I can help you find information on the internet. What would you like me to search for?"

# Say the introduction message
engine.say(intro_msg)
engine.runAndWait()

# Initialize the speech recognizer
r = sr.Recognizer()

# Start the chat loop
while True:
    # Listen for user input through the microphone
    with sr.Microphone() as source:
        SpeakText("Say something!")
        print("Listening....")
        audio = r.listen(source)

    # Convert the speech input to text
    try:
        user_input = r.recognize_google(audio)
        SpeakText(f"You said: {user_input}")

    # Handle any errors that occur during speech recognition
    except sr.UnknownValueError:
        user_input = ""

    # If the user says goodbye, exit the chat loop
    if user_input.lower() in ["goodbye", "bye", "exit", "quit"]:
        SpeakText("Goodbye!")
        print("Goodbye!")
        break

    # Otherwise, search for the user's query on Google and read out the first 5 sentences of the search result
    else:
        try:
            # Search for the user's query
            search_results = list(googlesearch.search(user_input, num_results=1))

            # Get the first result
            first_result = search_results[0]

            # Retrieve the HTML content of the first result page
            page = requests.get(first_result)
            soup = BeautifulSoup(page.content, 'html.parser')

            # Extract the first 5 sentences of the page's text
            text = ' '.join([p.text for p in soup.find_all('p')]) # concatenate all paragraphs into one string
            sentences = text.split('. ')[:5] # split into sentences and take the first 5

            # Say the sentences
            engine.say(f"The top search result for {user_input} is:")
            engine.runAndWait()
           for sentence in sentences:
                engine.say(sentence)
                engine.runAndWait()

            # Signal the end of search results
            engine.say("Search results have ended.")
            engine.runAndWait()
 
        # Handle any errors that occur during the search
        except:
            engine.say("Sorry, I couldn't find any results for that search.")
            engine.runAndWait()

# %%
import pyttsx3
import speech_recognition as sr
import googlesearch
import requests
from bs4 import BeautifulSoup

def SpeakText(command):
    engine=pyttsx3.init()
    engine.say(command)
    engine.runAndWait()
# Initialize the speech engine
engine = pyttsx3.init()
engine.setProperty('rate', 190)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[1].id)

# Define the bot's name and introduction message
bot_name = "Julia"
intro_msg = f"Hi, I'm {bot_name}. I can help you find information on the internet. What would you like me to search for?"

# Say the introduction message
engine.say(intro_msg)
engine.runAndWait()

# Initialize the speech recognizer
r = sr.Recognizer()

# Start the chat loop
while True:
    # Listen for user input through the microphone
    with sr.Microphone() as source:
        SpeakText("Say something!")
        print("Listening.....")
        audio = r.listen(source)

    # Convert the speech input to text
    try:
        user_input = r.recognize_google(audio)
        SpeakText(f"You said: {user_input}")

    # Handle any errors that occur during speech recognition
    except sr.UnknownValueError:
        user_input = ""

    # If the user says goodbye, exit the chat loop
    if user_input.lower() in ["goodbye", "bye", "exit", "quit"]:
        SpeakText("Goodbye!")
        break

    # Otherwise, search for the user's query on Google and read out the first 5 sentences of the search result
    else:
        try:
            # Search for the user's query
            search_results = list(googlesearch.search(user_input, num_results=1))

            # Get the first result
            first_result = search_results[0]

            # Retrieve the HTML content of the first result page
            page = requests.get(first_result)
            soup = BeautifulSoup(page.content, 'html.parser')

            # Extract the first 5 sentences of the page's text
            text = ' '.join([p.text for p in soup.find_all('p')]) # concatenate all paragraphs into one string
            sentences = text.split('. ')[:3] # split into sentences and take the first 2

            # Say the sentences
            engine.say(f"The top search result for {user_input} is:")
            engine.runAndWait()
            for sentence in sentences:
                engine.say(sentence)
                engine.runAndWait()
                print(sentence)

            # Signal the end of search results
            engine.say("Search results have ended.")
            engine.runAndWait()

        # Handle any errors that occur during the search
        except:
            engine.say("Sorry, I couldn't find any results for that search.")
            engine.runAndWait()
